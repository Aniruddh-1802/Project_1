# %%
import pandas as pd
analytics_df = pd.read_csv(r"C:\Users\aniruddh.singh\Documents\Project_1\outputs\grid_hour_analytics.csv")

# %%
print(analytics_df.columns.to_list())
print(analytics_df.head())
print(analytics_df.shape)
# Out:
# ['date', 'hour', 'grid_id', 'total_sms', 'total_calls', 'internet_activity', 'total_activity']
#          date  hour  grid_id  total_sms  total_calls  internet_activity  \
# 0  2013-11-01     0        1     3.1890       1.0212            57.7990
# 1  2013-11-01     0        2     3.1795       1.0402            57.9149
# 2  2013-11-01     0        3     3.1693       1.0604            58.0382
# 3  2013-11-01     0        4     3.2166       0.9663            57.4634
# 4  2013-11-01     0        5     2.9147       0.8850            52.1714
#
#    total_activity
# 0         62.0092
# 1         62.1346
# 2         62.2679
# 3         61.6463
# 4         55.9711
# (240000, 7)
